# %%
import pandas as pd
data = pd.read_csv("ftp_or.csv")
data
# Out:
#      Date\tTime\tSP_Thro\tUDPi_SpeedDemand\tC_SPDDYN\tC_SPDDEV\tUDPi_TorqueDemand\tC_TRQENG\tC_BHP\tU_BPOW\tU_BMEP\tU_BSFC\tM_BATT-S\tM_RELHUM\tM_FRAIRW\tM_FRAIRSIERRA\tM_FRFUEL\tU_FREXG\tM_UEGO01\tC_LAMBDAV\tC_LAMBDAS\tC_LAMBDAS-2\tC_LAMBDADIF\tC_CBAL\tP_AMBL\tP_INLET\tP_COMPOUT\tP_CACOUT\tP_CACDELP\tP_INTAKE\tP_BEGRCOOLER\tP_AEGRCOOLER\tP_TURBOUT\tP_DOCIN\tP_SCROUT\tP_COOLIN\tP_COOLOUT\tP_FUELIN\tP_FUELOUT\tP_OILGALL\tP_CCP\tT_AMB\tT_INLET\tT_COMPOUT\tT_CACOUT\tT_INTAKE\tT_BEGCOOLER\tT_AEGCOOLER\tT_TURBOUT\tT_DOCIN\tT_SCROUT\tT_COOLIN\tT_COOLOUT\tT_RADH2OIN\tT_RADH2OOUT\tT_CACH2OIN\tT_CACH2OOUT\tT_FUELIN\tT_FUELOUT\tT_OILGALL\tT_OILPAN\tE_CH4W\tE_CH4W2\tE_CO2D\tE_CO2Dlo\tE_CO2W\tE_CO2W2\tE_COHD\tE_COHD2\tE_COHW\tE_COHW2\tE_COLD\tE_COLD2\tE_COLW\tE_COLW2\tE_NOD\tE_NOD2\tE_NOW\tE_NOW2\tE_NOXD\tE_NOXD2\tE_NOXW\tE_NOXW2\tE_O2D\tE_O2D2\tE_O2W\tE_O2W2\tE_THCW\tE_THCW2\tE_EGR\tC_EGRBG\tM_SMOKE\tM_MKS1_NOX\tM_MKS1_N2O\tM_MKS1_NO\tM_MKS1_NO2\tM_MKS1_CO\tM_MKS1_CO2\tM_MKS1_NH3\tE_CO2EGR\tU_S
# ...
